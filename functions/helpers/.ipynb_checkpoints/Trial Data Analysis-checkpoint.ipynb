# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %%
#!pip install xlrd

# %%
# set up file names and read into dataframes
# accept input filenames from NodeJS server
ngo_filename = "5_NGO_database.xlsx"
hohk_programs_filename = "4_HandsOnProgram.xls"
volunteer_filename = "2_Dummy_Volunteer_Data.xls"
ngo_df = pd.read_excel(ngo_filename)
programs_df = pd.read_excel(hohk_programs_filename)
volunteers_df = pd.read_excel(volunteer_filename)

# %%
# drop irrelevant columns and reset index
colsToDropNgo = [0, 2, 3, 7, 8, 9, 10, 12, 15, 16, 17, 19, 21, 22, 24, 25, 26, 27, 30, 31,32,33, 34]
ngo_df.drop(ngo_df.columns[colsToDropNgo], axis=1, inplace=True)
ngo_df.index = np.arange(1,len(ngo_df)+1)
ngo_df.head()
# Out:
#   Organization Name \n(Eng + Chinese, alphabetical order)  \
# 1                                 Community Center A
# 2                                 Community Center B
# 3                                 Community Center C
# 4                                  Enviromental Org
# 5                                 Community Center D
#
#                                 Focus Area\n  \
# 1  Others, please state in population served
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
#
#   Served Population Groups \n(e.g. Elderly, Children & Youth, Domestic Helper, EM, Family etc.)  \
# 1                                        Human right
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#            Condition/Description of the Served Group  \
# 1                                                NaN
# 2                        Southern District residents
# 3                               (Volunteer matching)
# 4                                                NaN
# 5  visual impairement, blind and partially sighte...
#
#                        Location No. of staff under the organization/centre  \
# 1              Wan Chai Station                                        NaN
# 2        Wong Chuk Hang Station                                        50+
# 3              Wan Chai Station                                        50+
# 4  Mui Wo/None MTR can reach to                                        NaN
# 5               Kai Tak station                                        NaN
#
#    No. of beneficiary under the organization/centre  \
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
#
#   Work with us before?\n(Yes / No) Year of cooperation  \
# 1                               No                 NaN
# 2                              Yes           2018+2019
# 3                              Yes                2018
# 4                              Yes           2018+2019
# 5                              Yes           2018+2019
#
#   Corporate Program Wish List: \nPractical information \n(e.g. what kind of program/activity, what’s feasible, how big is the scale, prefered timing, any focus topic this year?)  \
# 1                                              Event
# 2                               EM Tutorial Sessions
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Skill Based volunteers/Pro bono workshop needs  \
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
#
#    Any facilities/activity rooms for program? (If Yes, please specify details - facilities type, room size…etc)
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN

# %%
# drop irrelevant columns and reset index
# also drop programs where status != active (cancelled or pending). can't do predictive modeling with time constraint. 
colsToDropProgs = [0, 5, 7, 8, 10, 11, 13, 14, 16, 17, 18]
programs_df.drop(programs_df.columns[colsToDropProgs], axis=1, inplace=True)
programs_df = programs_df[programs_df.Status == 'Active']
programs_df.index = np.arange(1,len(programs_df)+1)
programs_df.head()
# Out:
#    Status  \
# 1  Active
# 2  Active
# 3  Active
# 4  Active
# 5  Active
#
#    Volunteer Opportunity: Total Hours Served- the hours of all occurences/service sessions under the volunteer service programs  \
# 1                                              306.0
# 2                                              306.0
# 3                                              194.0
# 4                                              194.0
# 5                                               85.0
#
#   Volunteer Opportunity: Populations Served  \
# 1       Environmental education; Integrated
# 2       Environmental education; Integrated
# 3                                Integrated
# 4                                Integrated
# 5                     Hunger & homelessness
#
#   Volunteer Opportunity: Primary Impact Area  \
# 1            Environmental Conservation ????
# 2            Environmental Conservation ????
# 3            Environmental Conservation ????
# 4            Environmental Conservation ????
# 5         Hunger & Homelessness ????????????
#
#    Volunteer Opportunity: Volunteer Opportunity Name                Location  \
# 1  Serve-A-Thon: Soap Recycling 1:30 p.m. session...            Soap Cycling
# 2  Serve-A-Thon: Soap Recycling 1:30 p.m. session...            Soap Cycling
# 3  Serve-A-Thon: Soap Recycling 10 a.m. session (...            Soap Cycling
# 4  Serve-A-Thon: Soap Recycling 10 a.m. session (...            Soap Cycling
# 5  Serve-A-Thon: Deliver Daily Necessities to Hom...  ImpactHK, Sham Shui Po
#
#   Opportunity Coordinator  Maximum Attendance  Total Attended  \
# 1       HandsOn Hong Kong                16.0             8.0
# 2       HandsOn Hong Kong                30.0            27.0
# 3       HandsOn Hong Kong                30.0            27.0
# 4       HandsOn Hong Kong                30.0            28.0
# 5       HandsOn Hong Kong                 3.0             7.0
#
#    Total Not Attended  \
# 1                 2.0
# 2                 0.0
# 3                 0.0
# 4                 0.0
# 5                 0.0
#
#    Total Hours Served (for each occurrence/service session)  \
# 1                                               16.0
# 2                                               54.0
# 3                                               54.0
# 4                                               56.0
# 5                                               14.0
#
#   Volunteer Opportunity: Record ID
# 1                  a0N0I00001AFCUy
# 2                  a0N0I00001AFCUy
# 3                  a0N0I00001AFCcJ
# 4                  a0N0I00001AFCcJ
# 5                  a0N0I00001AFOJF

# %%
# drop columns and reset index
colsToDropVols = [0, 1, 5, 6, 7, 14]
volunteers_df.drop(volunteers_df.columns[colsToDropVols], axis=1, inplace=True)
volunteers_df.index = np.arange(1,len(volunteers_df)+1)
volunteers_df.head()
# Out:
#                                            Interests  Gender  \
# 1                                                NaN  Female
# 2                                                NaN  Female
# 3                                                NaN  Female
# 4  Education and Empowerment for Children and You...  Female
# 5  Education and Empowerment for Children and You...  Female
#
#   Employment Status              Attendance Status  Connections: Hours Served  \
# 1             Other  Attended (and Hours Verified)                       1.50
# 2             Other  Attended (and Hours Verified)                       1.50
# 3             Other  Attended (and Hours Verified)                       1.50
# 4           Retired  Attended (and Hours Verified)                       2.00
# 5           Retired  Attended (and Hours Verified)                       1.17
#
#    Contact: Hours Served (since account was created)  \
# 1                                              25.24
# 2                                              25.24
# 3                                              25.24
# 4                                              13.76
# 5                                              13.76
#
#    Volunteer Opportunity: Volunteer Opportunity Name  \
# 1  Help Primary & Secondary School Kids of Hong K...
# 2  Help Primary & Secondary School Kids of Hong K...
# 3  Serve-A-Thon: Help Homework Group with Childre...
# 4            Help Out at Hotmeal Service in Wan Chai
# 5  Help Ethnic Minority Primary Students with Sch...
#
#   Volunteer Opportunity: Managing Organization: Organization Name  \
# 1                            HandsOn Hong Kong ?????
# 2                            HandsOn Hong Kong ?????
# 3                            HandsOn Hong Kong ?????
# 4                            HandsOn Hong Kong ?????
# 5                            HandsOn Hong Kong ?????
#
#   Volunteer Opportunity: Type       Contact ID
# 1                     Project  0030I00001KzFwb
# 2                     Project  0030I00001KzFwb
# 3                     Project  0030I00001KzFwb
# 4                     Project  0030I00001LHaSZ
# 5                     Project  0030I00001LHaSZ

# %%
# improving column-names' readability
ngo_df.columns = ['OrganizationName', 'FocusArea', 'ServedPopulationGroups', 'GroupsDescription', 'Location', 'NumOfStaff', 'NumOfBeneficiaries', 'WorkWithUsBefore', 'YearOfCooperation', 'WishList/PracticalInformation', 'SkillBasedVolunteerNeeds', 'AnyFacilitiesOrRooms']
programs_df.columns = ['Status', 'TotalHoursServedUnderProgram', 'PopulationsServed', 'PrimaryImpactArea', 'VolunteerOpportunityName', 'Location', 'OpportunityCoordinator', 'MaxAttendance', 'TotalAttended', 'TotalNotAttended', 'TotalHoursServedForEachOccurrence', 'OpportunityRecordID']
volunteers_df.columns = ['Interests', 'Gender', 'EmploymentStatus', 'AttendanceStatus', 'Connections:HoursServed', 'Contact:HoursServed', 'VolunteerOpportunityName', 'VolunteerOpportunityManagingOrgName', 'VolunteerOpportunityType', 'ContactID']

# %%
ngo_df.head()
# Out:
#      OrganizationName                                  FocusArea  \
# 1  Community Center A  Others, please state in population served
# 2  Community Center B                                        NaN
# 3  Community Center C                                        NaN
# 4   Enviromental Org                                         NaN
# 5  Community Center D                                        NaN
#
#   ServedPopulationGroups                                  GroupsDescription  \
# 1            Human right                                                NaN
# 2                    NaN                        Southern District residents
# 3                    NaN                               (Volunteer matching)
# 4                    NaN                                                NaN
# 5                    NaN  visual impairement, blind and partially sighte...
#
#                        Location NumOfStaff  NumOfBeneficiaries  \
# 1              Wan Chai Station        NaN                 NaN
# 2        Wong Chuk Hang Station        50+                 NaN
# 3              Wan Chai Station        50+                 NaN
# 4  Mui Wo/None MTR can reach to        NaN                 NaN
# 5               Kai Tak station        NaN                 NaN
#
#   WorkWithUsBefore YearOfCooperation WishList/PracticalInformation  \
# 1               No               NaN                         Event
# 2              Yes         2018+2019          EM Tutorial Sessions
# 3              Yes              2018                           NaN
# 4              Yes         2018+2019                           NaN
# 5              Yes         2018+2019                           NaN
#
#    SkillBasedVolunteerNeeds  AnyFacilitiesOrRooms
# 1                       NaN                   NaN
# 2                       NaN                   NaN
# 3                       NaN                   NaN
# 4                       NaN                   NaN
# 5                       NaN                   NaN

# %%
programs_df.head()
# Out:
#    Status  TotalHoursServedUnderProgram                    PopulationsServed  \
# 1  Active                         306.0  Environmental education; Integrated
# 2  Active                         306.0  Environmental education; Integrated
# 3  Active                         194.0                           Integrated
# 4  Active                         194.0                           Integrated
# 5  Active                          85.0                Hunger & homelessness
#
#                     PrimaryImpactArea  \
# 1     Environmental Conservation ????
# 2     Environmental Conservation ????
# 3     Environmental Conservation ????
# 4     Environmental Conservation ????
# 5  Hunger & Homelessness ????????????
#
#                             VolunteerOpportunityName                Location  \
# 1  Serve-A-Thon: Soap Recycling 1:30 p.m. session...            Soap Cycling
# 2  Serve-A-Thon: Soap Recycling 1:30 p.m. session...            Soap Cycling
# 3  Serve-A-Thon: Soap Recycling 10 a.m. session (...            Soap Cycling
# 4  Serve-A-Thon: Soap Recycling 10 a.m. session (...            Soap Cycling
# 5  Serve-A-Thon: Deliver Daily Necessities to Hom...  ImpactHK, Sham Shui Po
#
#   OpportunityCoordinator  MaxAttendance  TotalAttended  TotalNotAttended  \
# 1      HandsOn Hong Kong           16.0            8.0               2.0
# 2      HandsOn Hong Kong           30.0           27.0               0.0
# 3      HandsOn Hong Kong           30.0           27.0               0.0
# 4      HandsOn Hong Kong           30.0           28.0               0.0
# 5      HandsOn Hong Kong            3.0            7.0               0.0
#
#    TotalHoursServedForEachOccurrence OpportunityRecordID
# 1                               16.0     a0N0I00001AFCUy
# 2                               54.0     a0N0I00001AFCUy
# 3                               54.0     a0N0I00001AFCcJ
# 4                               56.0     a0N0I00001AFCcJ
# 5                               14.0     a0N0I00001AFOJF

# %%
volunteers_df.head()
# Out:
#                                            Interests  Gender EmploymentStatus  \
# 1                                                NaN  Female            Other
# 2                                                NaN  Female            Other
# 3                                                NaN  Female            Other
# 4  Education and Empowerment for Children and You...  Female          Retired
# 5  Education and Empowerment for Children and You...  Female          Retired
#
#                 AttendanceStatus  Connections:HoursServed  \
# 1  Attended (and Hours Verified)                     1.50
# 2  Attended (and Hours Verified)                     1.50
# 3  Attended (and Hours Verified)                     1.50
# 4  Attended (and Hours Verified)                     2.00
# 5  Attended (and Hours Verified)                     1.17
#
#    Contact:HoursServed                           VolunteerOpportunityName  \
# 1                25.24  Help Primary & Secondary School Kids of Hong K...
# 2                25.24  Help Primary & Secondary School Kids of Hong K...
# 3                25.24  Serve-A-Thon: Help Homework Group with Childre...
# 4                13.76            Help Out at Hotmeal Service in Wan Chai
# 5                13.76  Help Ethnic Minority Primary Students with Sch...
#
#   VolunteerOpportunityManagingOrgName VolunteerOpportunityType  \
# 1             HandsOn Hong Kong ?????                  Project
# 2             HandsOn Hong Kong ?????                  Project
# 3             HandsOn Hong Kong ?????                  Project
# 4             HandsOn Hong Kong ?????                  Project
# 5             HandsOn Hong Kong ?????                  Project
#
#          ContactID
# 1  0030I00001KzFwb
# 2  0030I00001KzFwb
# 3  0030I00001KzFwb
# 4  0030I00001LHaSZ
# 5  0030I00001LHaSZ

# %%
# volunteers by age
femaleCount = volunteers_df['Gender'].value_counts()['Female']
maleCount = volunteers_df['Gender'].value_counts()['Male']
genderGraph = [[femaleCount, maleCount], ["Female", "Male"]]
genderGraph
# Out:
# [[84, 15], ['Female', 'Male']]

# %%
programs_df['EventType'] = programs_df['VolunteerOpportunityName']

# %%
programs_df.head()
# Out:
#    Status  TotalHoursServedUnderProgram                    PopulationsServed  \
# 1  Active                         306.0  Environmental education; Integrated
# 2  Active                         306.0  Environmental education; Integrated
# 3  Active                         194.0                           Integrated
# 4  Active                         194.0                           Integrated
# 5  Active                          85.0                Hunger & homelessness
#
#                     PrimaryImpactArea  \
# 1     Environmental Conservation ????
# 2     Environmental Conservation ????
# 3     Environmental Conservation ????
# 4     Environmental Conservation ????
# 5  Hunger & Homelessness ????????????
#
#                             VolunteerOpportunityName                Location  \
# 1  Serve-A-Thon: Soap Recycling 1:30 p.m. session...            Soap Cycling
# 2  Serve-A-Thon: Soap Recycling 1:30 p.m. session...            Soap Cycling
# 3  Serve-A-Thon: Soap Recycling 10 a.m. session (...            Soap Cycling
# 4  Serve-A-Thon: Soap Recycling 10 a.m. session (...            Soap Cycling
# 5  Serve-A-Thon: Deliver Daily Necessities to Hom...  ImpactHK, Sham Shui Po
#
#   OpportunityCoordinator  MaxAttendance  TotalAttended  TotalNotAttended  \
# 1      HandsOn Hong Kong           16.0            8.0               2.0
# 2      HandsOn Hong Kong           30.0           27.0               0.0
# 3      HandsOn Hong Kong           30.0           27.0               0.0
# 4      HandsOn Hong Kong           30.0           28.0               0.0
# 5      HandsOn Hong Kong            3.0            7.0               0.0
#
#    TotalHoursServedForEachOccurrence OpportunityRecordID  \
# 1                               16.0     a0N0I00001AFCUy
# 2                               54.0     a0N0I00001AFCUy
# 3                               54.0     a0N0I00001AFCcJ
# 4                               56.0     a0N0I00001AFCcJ
# 5                               14.0     a0N0I00001AFOJF
#
#                                            EventType
# 1  Serve-A-Thon: Soap Recycling 1:30 p.m. session...
# 2  Serve-A-Thon: Soap Recycling 1:30 p.m. session...
# 3  Serve-A-Thon: Soap Recycling 10 a.m. session (...
# 4  Serve-A-Thon: Soap Recycling 10 a.m. session (...
# 5  Serve-A-Thon: Deliver Daily Necessities to Hom...

# %%
#programs_df.EventType = programs_df.EventType.split(':')[0]
for i in range(1, len(programs_df.EventType)+1):
    programs_df.EventType[i] = programs_df.EventType[i].split(':')[0]
    #programs_df.EventType[
    #print(i)
# Out:
# c:\users\bevan\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
programs_df.EventType
# Out:
# 1                                           Serve-A-Thon
# 2                                           Serve-A-Thon
# 3                                           Serve-A-Thon
# 4                                           Serve-A-Thon
# 5                                           Serve-A-Thon
#                              ...
# 399                                    Youth Opportunity
# 400                                    Youth Opportunity
# 401                                    Youth Opportunity
# 402                                    Youth Opportunity
# 403    Help at Play Group with Students with Intellec...
# Name: EventType, Length: 403, dtype: object

# %%
programs_df.EventType.value_counts(ascending=False)
# Out:
# Youth Opportunity                                                                143
# Serve-A-Thon                                                                      59
# Youth Opportunities                                                               47
# COVID-19 Relief                                                                   28
# Phone call support to 1 elderly individual [PRE-TRAINED VOLUNTEERS ONLY]          26
# Family Opportunity                                                                23
# Youth opportunity                                                                 19
# Serve-a-thon                                                                      15
# Be a Sports Class Assistant for People with Special Needs                         12
# Help Hearing-Impaired Children with Schoolwork in To Kwa Wan                       6
# Help Ethnic Minority Children with Homework in Jordan                              4
# Help and Be the Storyteller at Story Telling Corner with Children                  2
# HandsOn Care Pack Delivery Volunteer Leader Information and Training Session       2
# 2020 VF Purpose Day - Wetland Habitat Preservation                                 2
# Training session                                                                   2
# Help Students with Intellectual Disabilities at Job-related Online Training        2
# Testing SBV                                                                        1
# Test_VO                                                                            1
# Help at Play Group with Students with Intellectual Disabilities                    1
# Help at Play Group with Students with Physical Disabilities                        1
# Online training session                                                            1
# LGT - (English) Phone call support to elderly [PRE-TRAINED VOLUNTEERS ONLY]        1
# Youth Empowered                                                                    1
# 2020 VF Purpose Week Pilot Program - Creating Educational Videos for Students      1
# LGT - (Cantonese) Phone call support to elderly [PRE-TRAINED VOLUNTEERS ONLY]      1
# Distributing Hygiene Kits to Street Cleaners                                       1
# 2020 VF Purpose Week - testing                                                     1
# Name: EventType, dtype: int64

# %%
programs_df.head()
# Out:
#    Status  TotalHoursServedUnderProgram                    PopulationsServed  \
# 1  Active                         306.0  Environmental education; Integrated
# 2  Active                         306.0  Environmental education; Integrated
# 3  Active                         194.0                           Integrated
# 4  Active                         194.0                           Integrated
# 5  Active                          85.0                Hunger & homelessness
#
#                     PrimaryImpactArea  \
# 1     Environmental Conservation ????
# 2     Environmental Conservation ????
# 3     Environmental Conservation ????
# 4     Environmental Conservation ????
# 5  Hunger & Homelessness ????????????
#
#                             VolunteerOpportunityName                Location  \
# 1  Serve-A-Thon: Soap Recycling 1:30 p.m. session...            Soap Cycling
# 2  Serve-A-Thon: Soap Recycling 1:30 p.m. session...            Soap Cycling
# 3  Serve-A-Thon: Soap Recycling 10 a.m. session (...            Soap Cycling
# 4  Serve-A-Thon: Soap Recycling 10 a.m. session (...            Soap Cycling
# 5  Serve-A-Thon: Deliver Daily Necessities to Hom...  ImpactHK, Sham Shui Po
#
#   OpportunityCoordinator  MaxAttendance  TotalAttended  TotalNotAttended  \
# 1      HandsOn Hong Kong           16.0            8.0               2.0
# 2      HandsOn Hong Kong           30.0           27.0               0.0
# 3      HandsOn Hong Kong           30.0           27.0               0.0
# 4      HandsOn Hong Kong           30.0           28.0               0.0
# 5      HandsOn Hong Kong            3.0            7.0               0.0
#
#    TotalHoursServedForEachOccurrence OpportunityRecordID     EventType
# 1                               16.0     a0N0I00001AFCUy  Serve-A-Thon
# 2                               54.0     a0N0I00001AFCUy  Serve-A-Thon
# 3                               54.0     a0N0I00001AFCcJ  Serve-A-Thon
# 4                               56.0     a0N0I00001AFCcJ  Serve-A-Thon
# 5                               14.0     a0N0I00001AFOJF  Serve-A-Thon

# %%
participationRate = programs_df.groupby(['EventType'])['MaxAttendance','TotalAttended']
# Out:
# c:\users\bevan\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
participationRateDF = participationRate.aggregate(np.sum)

# %%
participationRateDF
# Out:
#                                                     MaxAttendance  \
# EventType
# 2020 VF Purpose Day - Wetland Habitat Preservation          100.0
# 2020 VF Purpose Week - testing                                3.0
# 2020 VF Purpose Week Pilot Program - Creating E...           20.0
# Be a Sports Class Assistant for People with Spe...           24.0
# COVID-19 Relief                                             144.0
# Distributing Hygiene Kits to Street Cleaners                 20.0
# Family Opportunity                                          379.0
# HandsOn Care Pack Delivery Volunteer Leader Inf...           30.0
# Help Ethnic Minority Children with Homework in ...           16.0
# Help Hearing-Impaired Children with Schoolwork ...           21.0
# Help Students with Intellectual Disabilities at...            8.0
# Help and Be the Storyteller at Story Telling Co...            2.0
# Help at Play Group with Students with Intellect...            2.0
# Help at Play Group with Students with Physical ...            2.0
# LGT - (Cantonese) Phone call support to elderly...           30.0
# LGT - (English) Phone call support to elderly [...            5.0
# Online training session                                     100.0
# Phone call support to 1 elderly individual [PRE...          517.0
# Serve-A-Thon                                                560.0
# Serve-a-thon                                                 54.0
# Test_VO                                                       3.0
# Testing SBV                                                   2.0
# Training session                                             50.0
# Youth Empowered                                              30.0
# Youth Opportunities                                         173.0
# Youth Opportunity                                           580.0
# Youth opportunity                                            76.0
#
#                                                     TotalAttended
# EventType
# 2020 VF Purpose Day - Wetland Habitat Preservation            0.0
# 2020 VF Purpose Week - testing                                0.0
# 2020 VF Purpose Week Pilot Program - Creating E...            0.0
# Be a Sports Class Assistant for People with Spe...            0.0
# COVID-19 Relief                                               0.0
# Distributing Hygiene Kits to Street Cleaners                 15.0
# Family Opportunity                                          156.0
# HandsOn Care Pack Delivery Volunteer Leader Inf...           26.0
# Help Ethnic Minority Children with Homework in ...            2.0
# Help Hearing-Impaired Children with Schoolwork ...            0.0
# Help Students with Intellectual Disabilities at...            0.0
# Help and Be the Storyteller at Story Telling Co...            2.0
# Help at Play Group with Students with Intellect...            0.0
# Help at Play Group with Students with Physical ...            0.0
# LGT - (Cantonese) Phone call support to elderly...            0.0
# LGT - (English) Phone call support to elderly [...            0.0
# Online training session                                      47.0
# Phone call support to 1 elderly individual [PRE...          215.0
# Serve-A-Thon                                                415.0
# Serve-a-thon                                                 37.0
# Test_VO                                                       0.0
# Testing SBV                                                   0.0
# Training session                                              0.0
# Youth Empowered                                               1.0
# Youth Opportunities                                           0.0
# Youth Opportunity                                           201.0
# Youth opportunity                                             0.0

# %%
participationRateDF['RateOfParticipation'] = participationRateDF.TotalAttended*100/participationRateDF.MaxAttendance

# %%
participationRateDF
# Out:
#                                                     MaxAttendance  \
# EventType
# 2020 VF Purpose Day - Wetland Habitat Preservation          100.0
# 2020 VF Purpose Week - testing                                3.0
# 2020 VF Purpose Week Pilot Program - Creating E...           20.0
# Be a Sports Class Assistant for People with Spe...           24.0
# COVID-19 Relief                                             144.0
# Distributing Hygiene Kits to Street Cleaners                 20.0
# Family Opportunity                                          379.0
# HandsOn Care Pack Delivery Volunteer Leader Inf...           30.0
# Help Ethnic Minority Children with Homework in ...           16.0
# Help Hearing-Impaired Children with Schoolwork ...           21.0
# Help Students with Intellectual Disabilities at...            8.0
# Help and Be the Storyteller at Story Telling Co...            2.0
# Help at Play Group with Students with Intellect...            2.0
# Help at Play Group with Students with Physical ...            2.0
# LGT - (Cantonese) Phone call support to elderly...           30.0
# LGT - (English) Phone call support to elderly [...            5.0
# Online training session                                     100.0
# Phone call support to 1 elderly individual [PRE...          517.0
# Serve-A-Thon                                                560.0
# Serve-a-thon                                                 54.0
# Test_VO                                                       3.0
# Testing SBV                                                   2.0
# Training session                                             50.0
# Youth Empowered                                              30.0
# Youth Opportunities                                         173.0
# Youth Opportunity                                           580.0
# Youth opportunity                                            76.0
#
#                                                     TotalAttended  \
# EventType
# 2020 VF Purpose Day - Wetland Habitat Preservation            0.0
# 2020 VF Purpose Week - testing                                0.0
# 2020 VF Purpose Week Pilot Program - Creating E...            0.0
# Be a Sports Class Assistant for People with Spe...            0.0
# COVID-19 Relief                                               0.0
# Distributing Hygiene Kits to Street Cleaners                 15.0
# Family Opportunity                                          156.0
# HandsOn Care Pack Delivery Volunteer Leader Inf...           26.0
# Help Ethnic Minority Children with Homework in ...            2.0
# Help Hearing-Impaired Children with Schoolwork ...            0.0
# Help Students with Intellectual Disabilities at...            0.0
# Help and Be the Storyteller at Story Telling Co...            2.0
# Help at Play Group with Students with Intellect...            0.0
# Help at Play Group with Students with Physical ...            0.0
# LGT - (Cantonese) Phone call support to elderly...            0.0
# LGT - (English) Phone call support to elderly [...            0.0
# Online training session                                      47.0
# Phone call support to 1 elderly individual [PRE...          215.0
# Serve-A-Thon                                                415.0
# Serve-a-thon                                                 37.0
# Test_VO                                                       0.0
# Testing SBV                                                   0.0
# Training session                                              0.0
# Youth Empowered                                               1.0
# Youth Opportunities                                           0.0
# Youth Opportunity                                           201.0
# Youth opportunity                                             0.0
#
#                                                     RateOfParticipation
# EventType
# 2020 VF Purpose Day - Wetland Habitat Preservation             0.000000
# 2020 VF Purpose Week - testing                                 0.000000
# 2020 VF Purpose Week Pilot Program - Creating E...             0.000000
# Be a Sports Class Assistant for People with Spe...             0.000000
# COVID-19 Relief                                                0.000000
# Distributing Hygiene Kits to Street Cleaners                  75.000000
# Family Opportunity                                            41.160950
# HandsOn Care Pack Delivery Volunteer Leader Inf...            86.666667
# Help Ethnic Minority Children with Homework in ...            12.500000
# Help Hearing-Impaired Children with Schoolwork ...             0.000000
# Help Students with Intellectual Disabilities at...             0.000000
# Help and Be the Storyteller at Story Telling Co...           100.000000
# Help at Play Group with Students with Intellect...             0.000000
# Help at Play Group with Students with Physical ...             0.000000
# LGT - (Cantonese) Phone call support to elderly...             0.000000
# LGT - (English) Phone call support to elderly [...             0.000000
# Online training session                                       47.000000
# Phone call support to 1 elderly individual [PRE...            41.586074
# Serve-A-Thon                                                  74.107143
# Serve-a-thon                                                  68.518519
# Test_VO                                                        0.000000
# Testing SBV                                                    0.000000
# Training session                                               0.000000
# Youth Empowered                                                3.333333
# Youth Opportunities                                            0.000000
# Youth Opportunity                                             34.655172
# Youth opportunity                                              0.000000
